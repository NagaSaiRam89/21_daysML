# %% [markdown]
# <a href="https://colab.research.google.com/github/NagaSaiRam89/21_daysML/blob/main/ML/Day_1_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris.head(5)
iris.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.shape
# Out:
# (150, 5)

# %%
rows , cols =  iris.shape

# %%
if rows >100 and cols> 10:
  print("more rows and less coloumns")
elif rows < 100 :
  print("less rows and more coloumns")
else:
  print("more rows and more coloumns")

iris.describe
# Out:
# more rows and more coloumns
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print(iris.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print(iris.duplicated().sum())
# Out:
# 1

# %%
iris.drop_duplicates(inplace=True)

# %% [markdown]
# Univarient analysis

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# Name: count, dtype: int64

# %%
sns.countplot(x='species', data = iris)
plt.title("distributions of species")
plt.show()

# %%
sns.histplot(iris['sepal_length'], kde=True)
plt.title("distributions of sepal_length")
plt.show()

# %%
sns.boxplot(x = iris['sepal_length'])
plt.title("distributions of sepal_length")
plt.show()

# %% [markdown]
# Bivariate Analysis
# Bivariate analysis examines the relationship between two variables.

# %%
sns.scatterplot(x='sepal_length', y='petal_length', data=iris)
plt.title("scatterplot of sepallength and the petal length")
plt.show()

# %%
correlation_matrix = iris.drop('species', axis=1).corr()
# print(corealtion_matrix)
sns.heatmap(correlation_matrix, annot =True, cmap='coolwarm')
plt.title("heatmap of corealtion matrix")
plt.show()

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  149 non-null    float64
#  1   sepal_width   149 non-null    float64
#  2   petal_length  149 non-null    float64
#  3   petal_width   149 non-null    float64
#  4   species       149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
sns.boxplot(x='species', y='sepal_length', data=iris)
plt.title("boxplot of species and sepal_length")
plt.show()

# %% [markdown]
# Multivariate Analysis
# Multivariate analysis involves analyzing more than two variables simultaneously.

# %%
sns.pairplot(iris, hue='species')
plt.title("pairplot of species")
plt.show()
